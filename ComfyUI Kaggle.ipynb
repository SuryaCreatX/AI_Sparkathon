# %%
HomePath = '/kaggle/working'

#**초기모델(checkpoint) URL**
Checkpoint_Url = 'https://civitai.com/api/download/models/141866?type=Model&format=SafeTensor&size=pruned&fp=fp16' 
#**초기모델 파일명**
Checkpoint_Filename = 'dark_sushi_25d_25d.safetensors'

#**ControlNet 기본 모델 다운로드**
#> *openpose, lineart, softedge, depth, canny, tile, ip2p*  
ControlNet = True #@param {type:"boolean"}

#**ControlNet 추가 모델 다운로드**
#> *segment, inpaint, scribble, mlsd, normalbae, suffle*  
ControlNet_Extra = True #@param {type:"boolean"}

#**T2I Adapter 모델 다운로드**
#> *style, color, sketch, zoedepth, recolor*  
ControlNet_T2I = False #@param {type:"boolean"}

#*추가익스텐션*

#**AnimateDiff for ComfyUI**
AnimateDiff_Evolved = True

#**ComfyUI IPAdapter plus**
IPAdapter_plus = True

#**ComfyUI Impact Pack**
ComfyUI_Impact_Pack = True

Workspace = 'ui'

# install util
# !apt update -qq
# !apt -y install -qq aria2

# python venv shortcut (conda create -n colabui -c cctbx202208 -y)
import os
if not os.path.isdir('/opt/conda/envs/colabui'):
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ninjaneural/webui/resolve/main/kaggle-torch2.0.1%2Bcuda118.tar.gz -d /kaggle/working -o kaggle-torch2.0.1+cuda118.tar.gz
    # %cd {HomePath}
    # !tar xzvf kaggle-torch2.0.1+cuda118.tar.gz -C / > /dev/null
    # !rm kaggle-torch2.0.1+cuda118.tar.gz

# !/opt/conda/envs/colabui/bin/python3 -m pip install opencv-python
# !/opt/conda/envs/colabui/bin/python3 -m pip install google-api-python-client
# !/opt/conda/envs/colabui/bin/python3 -m pip install scikit-image
# !/opt/conda/envs/colabui/bin/python3 -m pip install matplotlib
# !/opt/conda/envs/colabui/bin/python3 -m pip install numba

# %cd {HomePath}
# !git clone https://github.com/comfyanonymous/ComfyUI {Workspace}
# %cd {HomePath}/{Workspace}
# !/opt/conda/envs/colabui/bin/python3 -m pip install -r requirements.txt

# custom nodes start
# %cd custom_nodes

# !git clone https://github.com/ltdrdata/ComfyUI-Manager
# !git clone https://github.com/Fannovel16/comfyui_controlnet_aux
# !git clone https://github.com/cubiq/ComfyUI_essentials
# !git clone https://github.com/rgthree/rgthree-comfy
# !git clone https://github.com/WASasquatch/was-node-suite-comfyui

# %cd ..

if AnimateDiff_Evolved:
  # !git clone https://github.com/Kosinkadink/ComfyUI-AnimateDiff-Evolved
  # !git clone https://github.com/Kosinkadink/ComfyUI-Advanced-ControlNet
  # !git clone https://github.com/Kosinkadink/ComfyUI-VideoHelperSuite
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/guoyww/animatediff/resolve/main/mm_sd_v15_v2.ckpt -d ./ComfyUI-AnimateDiff-Evolved/models/ -o mm_sd_v15_v2.ckpt
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/guoyww/animatediff/resolve/main/mm_sd_v15.ckpt -d ./ComfyUI-AnimateDiff-Evolved/models/ -o mm_sd_v15.ckpt
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/guoyww/animatediff/resolve/main/mm_sd_v14.ckpt -d ./ComfyUI-AnimateDiff-Evolved/models/ -o mm_sd_v14.ckpt
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/CiaraRowles/TemporalDiff/resolve/main/temporaldiff-v1-animatediff.ckpt -d ./ComfyUI-AnimateDiff-Evolved/models/ -o temporaldiff-v1-animatediff.ckpt
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/guoyww/animatediff/resolve/main/v2_lora_PanLeft.ckpt -d ./ComfyUI-AnimateDiff-Evolved/motion_lora/ -o v2_lora_PanLeft.ckpt
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/guoyww/animatediff/resolve/main/v2_lora_PanRight.ckpt -d ./ComfyUI-AnimateDiff-Evolved/motion_lora/ -o v2_lora_PanRight.ckpt
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/guoyww/animatediff/resolve/main/v2_lora_ZoomOut.ckpt -d ./ComfyUI-AnimateDiff-Evolved/motion_lora/ -o v2_lora_ZoomOut.ckpt
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/guoyww/animatediff/resolve/main/v2_lora_ZoomIn.ckpt -d ./ComfyUI-AnimateDiff-Evolved/motion_lora/ -o v2_lora_ZoomIn.ckpt
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/guoyww/animatediff/resolve/main/v2_lora_TiltUp.ckpt -d ./ComfyUI-AnimateDiff-Evolved/motion_lora/ -o v2_lora_TiltUp.ckpt
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/guoyww/animatediff/resolve/main/v2_lora_TiltDown.ckpt -d ./ComfyUI-AnimateDiff-Evolved/motion_lora/ -o v2_lora_TiltDown.ckpt

if IPAdapter_plus:
  # !git clone https://github.com/cubiq/ComfyUI_IPAdapter_plus
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/h94/IP-Adapter/resolve/main/models/ip-adapter_sd15.bin -d ./ComfyUI_IPAdapter_plus/models/ -o ip-adapter_sd15.bin
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/h94/IP-Adapter/resolve/main/models/ip-adapter-plus_sd15.bin -d ./ComfyUI_IPAdapter_plus/models/ -o ip-adapter-plus_sd15.bin
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/h94/IP-Adapter/resolve/main/models/ip-adapter-plus-face_sd15.bin -d ./ComfyUI_IPAdapter_plus/models/ -o ip-adapter-plus-face_sd15.bin
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/h94/IP-Adapter/resolve/main/models/ip-adapter_sd15_light.bin -d ./ComfyUI_IPAdapter_plus/models/ -o ip-adapter_sd15_light.bin
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/h94/IP-Adapter/resolve/main/models/image_encoder/model.safetensors -d ../models/clip_vision/ -o model.safetensors
  
if ComfyUI_Impact_Pack:
  # !git clone https://github.com/ltdrdata/ComfyUI-Impact-Pack

# # 다운만 받으면 되는 노드
# !git clone https://github.com/RockOfFire/ComfyUI_Comfyroll_CustomNodes.git

# # 추가 인스톨해야 하는 노드
# !git clone https://github.com/WASasquatch/was-node-suite-comfyui
# %cd was-node-suite-comfyui
# !/opt/conda/envs/colabui/bin/python3 -m pip install -r requirements.txt
# %cd ..
    
# custom nodes end
# %cd {HomePath}/{Workspace}

# checkpoint 
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M "{Checkpoint_Url}" -d ./models/checkpoints -o {Checkpoint_Filename}

# upscaler
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/sberbank-ai/Real-ESRGAN/resolve/main/RealESRGAN_x4.pth -d ./models/upscale_models -o RealESRGAN_x4.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/embed/upscale/resolve/main/4x-UltraSharp.pth -d ./models/upscale_models -o 4x-UltraSharp.pth

# vae
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt -d ./models/vae -o vae-ft-mse-840000-ema-pruned.vae.pt

# lora
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M "https://civitai.com/api/download/models/87153?type=Model&format=SafeTensor" -d ./models/loras -o more_details.safetensors

# embeddings
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/datasets/gsdf/EasyNegative/resolve/main/EasyNegative.pt -d ./models/embeddings -o EasyNegative.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/AsciiP/badhandv4/resolve/main/badhandv4.pt -d ./models/embeddings -o badhandv4.pt

# input dataset lora
# !ln -s /kaggle/input/webui-lora ./models/loras/input

# input dataset LyCORIS
# !ln -s /kaggle/input/webui-lycoris ./models/loras/input

# input dataset hypernetwork
# !ln -s /kaggle/input/webui-hypernetwork ./models/hypernetworks/input

# input dataset checkpoint
#!ln -s /kaggle/input/webui-checkpoint ./models/checkpoints/input

# controlnet model
if ControlNet:
  ControlNet_Model_Path = "./models/controlnet"

  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_openpose_fp16.safetensors -d {ControlNet_Model_Path} -o control_v11p_sd15_openpose_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_lineart_fp16.safetensors -d {ControlNet_Model_Path} -o control_v11p_sd15_lineart_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_softedge_fp16.safetensors -d {ControlNet_Model_Path} -o control_v11p_sd15_softedge_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11f1p_sd15_depth_fp16.safetensors -d {ControlNet_Model_Path} -o control_v11f1p_sd15_depth_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_canny_fp16.safetensors -d {ControlNet_Model_Path} -o control_v11p_sd15_canny_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11f1e_sd15_tile_fp16.safetensors -d {ControlNet_Model_Path} -o control_v11f1e_sd15_tile_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11e_sd15_ip2p_fp16.safetensors -d {ControlNet_Model_Path} -o control_v11e_sd15_ip2p_fp16.safetensors

  if ControlNet_Extra:
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_seg_fp16.safetensors -d {ControlNet_Model_Path} -o control_v11p_sd15_seg_fp16.safetensors
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15s2_lineart_anime_fp16.safetensors -d {ControlNet_Model_Path} -o control_v11p_sd15s2_lineart_anime_fp16.safetensors
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_inpaint_fp16.safetensors -d {ControlNet_Model_Path} -o control_v11p_sd15_inpaint_fp16.safetensors
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_scribble_fp16.safetensors -d {ControlNet_Model_Path} -o control_v11p_sd15_scribble_fp16.safetensors

    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_mlsd_fp16.safetensors -d {ControlNet_Model_Path} -o control_v11p_sd15_mlsd_fp16.safetensors
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_normalbae_fp16.safetensors -d {ControlNet_Model_Path} -o control_v11p_sd15_normalbae_fp16.safetensors
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11e_sd15_shuffle_fp16.safetensors -d {ControlNet_Model_Path} -o control_v11e_sd15_shuffle_fp16.safetensors
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/CiaraRowles/TemporalNet/resolve/main/diff_control_sd15_temporalnet_fp16.safetensors -d {ControlNet_Model_Path} -o diff_control_sd15_temporalnet_fp16.safetensors

  if ControlNet_T2I:
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/TencentARC/T2I-Adapter/resolve/main/models/t2iadapter_style_sd14v1.pth -d {ControlNet_Model_Path} -o t2iadapter_style_sd14v1.pth
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/TencentARC/T2I-Adapter/resolve/main/models/t2iadapter_color_sd14v1.pth -d {ControlNet_Model_Path} -o t2iadapter_color_sd14v1.pth
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/TencentARC/T2I-Adapter/resolve/main/models/t2iadapter_sketch_sd15v2.pth -d {ControlNet_Model_Path} -o t2iadapter_sketch_sd15v2.pth
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/TencentARC/T2I-Adapter/resolve/main/models/t2iadapter_zoedepth_sd15v1.pth -d .{ControlNet_Model_Path} -o t2iadapter_zoedepth_sd15v1.pth
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/ioclab_sd15_recolor.safetensors -d {ControlNet_Model_Path} -o ioclab_sd15_recolor.safetensors  

# localtunnel
# !npm install -g localtunnel

import subprocess
import threading
import time
import socket
import urllib.request

def iframe_thread(port):
    while True:
        time.sleep(0.5)
        sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
        result = sock.connect_ex(('127.0.0.1', port))
        if result == 0:
            break
        sock.close()
    print("\nComfyUI finished loading, trying to launch localtunnel (if it gets stuck here localtunnel is having issues)\n")
    print("The password/enpoint ip for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
    print("localtunnel 웹페이지를 열면 위의 숫자들을 입력해주세요")
    p = subprocess.Popen(["lt", "--port", "{}".format(port)], stdout=subprocess.PIPE)
    for line in p.stdout:
        print(line.decode(), end='')

# !conda clean --all -y

print("설치 완료! 시작을 실행해주세요")
# Out:
# W: http://packages.cloud.google.com/apt/dists/gcsfuse-focal/InRelease: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.
# E: Repository 'http://packages.cloud.google.com/apt gcsfuse-focal InRelease' changed its 'Origin' value from 'gcsfuse-jessie' to 'gcsfuse-focal'
# E: Repository 'http://packages.cloud.google.com/apt gcsfuse-focal InRelease' changed its 'Label' value from 'gcsfuse-jessie' to 'gcsfuse-focal'
# W: https://packages.cloud.google.com/apt/dists/google-fast-socket/InRelease: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.
# The following additional packages will be installed:
#   libaria2-0 libc-ares2 libssh2-1
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2 libssh2-1
# 0 upgraded, 4 newly installed, 0 to remove and 190 not upgraded.
# Need to get 1622 kB of archives.
# After this operation, 5817 kB of additional disk space will be used.
#
# 78Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 113818 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.18.1-1ubuntu0.22.04.3_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 87Progress: [  6%] [###.......................................................] 8Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# 7Progress: [ 12%] [######....................................................] 8Selecting previously unselected package libssh2-1:amd64.
# Preparing to unpack .../libssh2-1_1.10.0-3_amd64.deb ...
# 7Progress: [ 18%] [##########................................................] 8Unpacking libssh2-1:amd64 (1.10.0-3) ...
# 7Progress: [ 24%] [#############.............................................] 8Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.36.0-1_amd64.deb ...
# 7Progress: [ 29%] [#################.........................................] 8Unpacking libaria2-0:amd64 (1.36.0-1) ...
# 7Progress: [ 35%] [####################......................................] 8Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.36.0-1_amd64.deb ...
# 7Progress: [ 41%] [#######################...................................] 8Unpacking aria2 (1.36.0-1) ...
# 7Progress: [ 47%] [###########################...............................] 8Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# 7Progress: [ 53%] [##############################............................] 87Progress: [ 59%] [##################################........................] 8Setting up libssh2-1:amd64 (1.10.0-3) ...
# 7Progress: [ 65%] [#####################################.....................] 87Progress: [ 71%] [########################################..................] 8Setting up libaria2-0:amd64 (1.36.0-1) ...
# 7Progress: [ 76%] [############################################..............] 87Progress: [ 82%] [###############################################...........] 8Setting up aria2 (1.36.0-1) ...
# 7Progress: [ 88%] [###################################################.......] 87Progress: [ 94%] [######################################################....] 8Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.1) ...
#
# [#9a77eb 2.2GiB/2.3GiB(93%) CN:16 DL:399MiB]0m]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 9a77eb|OK  |   396MiB/s|/kaggle/working/kaggle-torch2.0.1+cuda118.tar.gz
#
# Status Legend:
# (OK):download completed.
# /kaggle/working
# Error in sitecustomize; set PYTHONVERBOSE for traceback:
# ModuleNotFoundError: No module named 'google'
# Collecting opencv-python
#   Downloading opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 21.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.19.3 in /opt/conda/envs/colabui/lib/python3.10/site-packages (from opencv-python) (1.26.0)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.10.0.84
# Error in sitecustomize; set PYTHONVERBOSE for traceback:
# ModuleNotFoundError: No module named 'google'
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.141.0-py2.py3-none-any.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 8.7 MB/s eta 0:00:00:00:010:01
# Collecting httplib2<1.dev0,>=0.19.0
#   Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 9.6 MB/s eta 0:00:00
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5
#   Downloading google_api_core-2.19.1-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 14.1 MB/s eta 0:00:00
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0
#   Downloading google_auth-2.33.0-py2.py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.5/200.5 kB 20.3 MB/s eta 0:00:00
# Collecting google-auth-httplib2<1.0.0,>=0.2.0
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Collecting uritemplate<5,>=3.0.1
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5
#   Downloading protobuf-5.27.3-cp38-abi3-manylinux2014_x86_64.whl (309 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.3/309.3 kB 29.1 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /opt/conda/envs/colabui/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.31.0)
# Collecting proto-plus<2.0.0dev,>=1.22.3
#   Downloading proto_plus-1.24.0-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 4.9 MB/s eta 0:00:00
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2
#   Downloading googleapis_common_protos-1.63.2-py2.py3-none-any.whl (220 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.0/220.0 kB 21.9 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.4.0-py3-none-any.whl (9.5 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.4.0-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.2/181.2 kB 17.1 MB/s eta 0:00:00
# Collecting pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2
#   Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 10.9 MB/s eta 0:00:00
# Collecting pyasn1<0.7.0,>=0.4.6
#   Downloading pyasn1-0.6.0-py2.py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 kB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/colabui/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/colabui/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/colabui/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/colabui/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.2.0)
# Installing collected packages: uritemplate, pyparsing, pyasn1, protobuf, cachetools, rsa, pyasn1-modules, proto-plus, httplib2, googleapis-common-protos, google-auth, google-auth-httplib2, google-api-core, google-api-python-client
# Successfully installed cachetools-5.4.0 google-api-core-2.19.1 google-api-python-client-2.141.0 google-auth-2.33.0 google-auth-httplib2-0.2.0 googleapis-common-protos-1.63.2 httplib2-0.22.0 proto-plus-1.24.0 protobuf-5.27.3 pyasn1-0.6.0 pyasn1-modules-0.4.0 pyparsing-3.1.2 rsa-4.9 uritemplate-4.1.1
# Collecting scikit-image
#   Downloading scikit_image-0.24.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 72.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: networkx>=2.8 in /opt/conda/envs/colabui/lib/python3.10/site-packages (from scikit-image) (3.1)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/envs/colabui/lib/python3.10/site-packages (from scikit-image) (1.26.0)
# Collecting scipy>=1.9
#   Downloading scipy-1.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.1/41.1 MB 32.1 MB/s eta 0:00:0000:0100:01
# Collecting lazy-loader>=0.4
#   Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Collecting tifffile>=2022.8.12
#   Downloading tifffile-2024.8.10-py3-none-any.whl (225 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.8/225.8 kB 22.0 MB/s eta 0:00:00
# Collecting packaging>=21
#   Downloading packaging-24.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=9.1 in /opt/conda/envs/colabui/lib/python3.10/site-packages (from scikit-image) (10.0.1)
# Collecting imageio>=2.33
#   Downloading imageio-2.35.0-py3-none-any.whl (315 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.4/315.4 kB 27.7 MB/s eta 0:00:00
# Installing collected packages: tifffile, scipy, packaging, imageio, lazy-loader, scikit-image
# Successfully installed imageio-2.35.0 lazy-loader-0.4 packaging-24.1 scikit-image-0.24.0 scipy-1.14.0 tifffile-2024.8.10
# Collecting matplotlib
#   Downloading matplotlib-3.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 63.8 MB/s eta 0:00:00:00:010:01
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (305 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.2/305.2 kB 26.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.23 in /opt/conda/envs/colabui/lib/python3.10/site-packages (from matplotlib) (1.26.0)
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/envs/colabui/lib/python3.10/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/envs/colabui/lib/python3.10/site-packages (from matplotlib) (10.0.1)
# Collecting python-dateutil>=2.7
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 21.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/colabui/lib/python3.10/site-packages (from matplotlib) (24.1)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 68.0 MB/s eta 0:00:00
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.53.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 88.4 MB/s eta 0:00:00:00:01
# Collecting six>=1.5
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: six, kiwisolver, fonttools, cycler, contourpy, python-dateutil, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.1 kiwisolver-1.4.5 matplotlib-3.9.2 python-dateutil-2.9.0.post0 six-1.16.0
# Collecting numba
#   Downloading numba-0.60.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 49.7 MB/s eta 0:00:0000:0100:01
# Collecting llvmlite<0.44,>=0.43.0dev0
#   Downloading llvmlite-0.43.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 MB 30.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy<2.1,>=1.22 in /opt/conda/envs/colabui/lib/python3.10/site-packages (from numba) (1.26.0)
# Installing collected packages: llvmlite, numba
# Successfully installed llvmlite-0.43.0 numba-0.60.0
# /kaggle/working
# Cloning into 'ui'...
# remote: Enumerating objects: 13006, done.
# remote: Counting objects: 100% (389/389), done.
# remote: Compressing objects: 100% (233/233), done.
# remote: Total 13006 (delta 216), reused 288 (delta 151), pack-reused 12617 (from 1)
# Receiving objects: 100% (13006/13006), 6.57 MiB | 23.62 MiB/s, done.
# Resolving deltas: 100% (8720/8720), done.
# /kaggle/working/ui
# Requirement already satisfied: torch in /opt/conda/envs/colabui/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (2.0.1+cu118)
# Collecting torchsde
#   Downloading torchsde-0.2.6-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: torchvision in /opt/conda/envs/colabui/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (0.15.2+cu118)
# Collecting torchaudio
#   Downloading torchaudio-2.4.0-cp310-cp310-manylinux1_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 52.9 MB/s eta 0:00:00a 0:00:01
# Collecting einops
#   Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 3.9 MB/s eta 0:00:00
# Collecting transformers>=4.28.1
#   Downloading transformers-4.44.0-py3-none-any.whl (9.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 90.9 MB/s eta 0:00:00:00:0100:01
# Collecting tokenizers>=0.13.3
#   Downloading tokenizers-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 80.6 MB/s eta 0:00:00:00:01
# Collecting sentencepiece
#   Downloading sentencepiece-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 68.0 MB/s eta 0:00:00
# Collecting safetensors>=0.4.2
#   Downloading safetensors-0.4.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (435 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 435.5/435.5 kB 34.3 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 66.3 MB/s eta 0:00:00
# Collecting pyyaml
#   Downloading PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (751 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 751.2/751.2 kB 52.1 MB/s eta 0:00:00
# Requirement already satisfied: Pillow in /opt/conda/envs/colabui/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (10.0.1)
# Requirement already satisfied: scipy in /opt/conda/envs/colabui/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (1.14.0)
# Collecting tqdm
#   Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 8.1 MB/s eta 0:00:00
# Collecting psutil
#   Downloading psutil-6.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.5/290.5 kB 27.0 MB/s eta 0:00:00
# Collecting kornia>=0.7.1
#   Downloading kornia-0.7.3-py2.py3-none-any.whl (833 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 833.3/833.3 kB 54.6 MB/s eta 0:00:00
# Collecting spandrel
#   Downloading spandrel-0.3.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.0/269.0 kB 24.5 MB/s eta 0:00:00
# Collecting soundfile
#   Downloading soundfile-0.12.1-py2.py3-none-manylinux_2_31_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 62.8 MB/s eta 0:00:00
# Requirement already satisfied: networkx in /opt/conda/envs/colabui/lib/python3.10/site-packages (from torch->-r requirements.txt (line 1)) (3.1)
# Requirement already satisfied: triton==2.0.0 in /opt/conda/envs/colabui/lib/python3.10/site-packages (from torch->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: typing-extensions in /opt/conda/envs/colabui/lib/python3.10/site-packages (from torch->-r requirements.txt (line 1)) (4.8.0)
# Requirement already satisfied: filelock in /opt/conda/envs/colabui/lib/python3.10/site-packages (from torch->-r requirements.txt (line 1)) (3.12.4)
# Requirement already satisfied: sympy in /opt/conda/envs/colabui/lib/python3.10/site-packages (from torch->-r requirements.txt (line 1)) (1.12)
# Requirement already satisfied: jinja2 in /opt/conda/envs/colabui/lib/python3.10/site-packages (from torch->-r requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: cmake in /opt/conda/envs/colabui/lib/python3.10/site-packages (from triton==2.0.0->torch->-r requirements.txt (line 1)) (3.27.5)
# Requirement already satisfied: lit in /opt/conda/envs/colabui/lib/python3.10/site-packages (from triton==2.0.0->torch->-r requirements.txt (line 1)) (16.0.6)
# Requirement already satisfied: numpy>=1.19 in /opt/conda/envs/colabui/lib/python3.10/site-packages (from torchsde->-r requirements.txt (line 2)) (1.26.0)
# Collecting trampoline>=0.1.2
#   Downloading trampoline-0.1.2-py3-none-any.whl (5.2 kB)
# Requirement already satisfied: requests in /opt/conda/envs/colabui/lib/python3.10/site-packages (from torchvision->-r requirements.txt (line 3)) (2.31.0)
# Collecting torchaudio
#   Downloading torchaudio-2.3.1-cp310-cp310-manylinux1_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 88.8 MB/s eta 0:00:00:00:01
#   Downloading torchaudio-2.3.0-cp310-cp310-manylinux1_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 90.4 MB/s eta 0:00:00:00:01
#   Downloading torchaudio-2.2.2-cp310-cp310-manylinux1_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 90.8 MB/s eta 0:00:00:00:01
#   Downloading torchaudio-2.2.1-cp310-cp310-manylinux1_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 88.4 MB/s eta 0:00:00:00:01
#   Downloading torchaudio-2.2.0-cp310-cp310-manylinux1_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 91.2 MB/s eta 0:00:00:00:01
#   Downloading torchaudio-2.1.2-cp310-cp310-manylinux1_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 85.8 MB/s eta 0:00:00:00:01
#   Downloading torchaudio-2.1.1-cp310-cp310-manylinux1_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 83.8 MB/s eta 0:00:00:00:01
#   Downloading torchaudio-2.1.0-cp310-cp310-manylinux1_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 83.7 MB/s eta 0:00:00:00:01
#   Downloading torchaudio-2.0.2-cp310-cp310-manylinux1_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 87.1 MB/s eta 0:00:00:00:01
# Collecting tokenizers>=0.13.3
#   Downloading tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 10.3 MB/s eta 0:00:00:00:01
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/colabui/lib/python3.10/site-packages (from transformers>=4.28.1->-r requirements.txt (line 6)) (24.1)
# Collecting huggingface-hub<1.0,>=0.23.2
#   Downloading huggingface_hub-0.24.5-py3-none-any.whl (417 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.5/417.5 kB 31.4 MB/s eta 0:00:00
# Collecting regex!=2019.12.17
#   Downloading regex-2024.7.24-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (776 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.5/776.5 kB 42.3 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.6/301.6 kB 28.9 MB/s eta 0:00:00
# Collecting attrs>=17.3.0
#   Downloading attrs-24.2.0-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 6.8 MB/s eta 0:00:00
# Collecting aiohappyeyeballs>=2.3.0
#   Downloading aiohappyeyeballs-2.3.5-py3-none-any.whl (12 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.5/239.5 kB 20.6 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.3/124.3 kB 10.9 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0
#   Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting kornia-rs>=0.1.0
#   Downloading kornia_rs-0.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 67.1 MB/s eta 0:00:00
# Collecting cffi>=1.0
#   Downloading cffi-1.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (445 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 445.9/445.9 kB 32.7 MB/s eta 0:00:00
# Collecting pycparser
#   Downloading pycparser-2.22-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.6/117.6 kB 11.6 MB/s eta 0:00:00
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2024.6.1-py3-none-any.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 14.9 MB/s eta 0:00:00
# Requirement already satisfied: idna>=2.0 in /opt/conda/envs/colabui/lib/python3.10/site-packages (from yarl<2.0,>=1.0->aiohttp->-r requirements.txt (line 10)) (3.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/envs/colabui/lib/python3.10/site-packages (from jinja2->torch->-r requirements.txt (line 1)) (2.1.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/colabui/lib/python3.10/site-packages (from requests->torchvision->-r requirements.txt (line 3)) (2023.7.22)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/colabui/lib/python3.10/site-packages (from requests->torchvision->-r requirements.txt (line 3)) (2.0.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/colabui/lib/python3.10/site-packages (from requests->torchvision->-r requirements.txt (line 3)) (3.2.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/envs/colabui/lib/python3.10/site-packages (from sympy->torch->-r requirements.txt (line 1)) (1.3.0)
# Installing collected packages: trampoline, sentencepiece, tqdm, safetensors, regex, pyyaml, pycparser, psutil, multidict, kornia-rs, fsspec, frozenlist, einops, attrs, async-timeout, aiohappyeyeballs, yarl, huggingface-hub, cffi, aiosignal, tokenizers, soundfile, aiohttp, transformers, torchsde, torchaudio, spandrel, kornia
# Successfully installed aiohappyeyeballs-2.3.5 aiohttp-3.10.3 aiosignal-1.3.1 async-timeout-4.0.3 attrs-24.2.0 cffi-1.17.0 einops-0.8.0 frozenlist-1.4.1 fsspec-2024.6.1 huggingface-hub-0.24.5 kornia-0.7.3 kornia-rs-0.1.5 multidict-6.0.5 psutil-6.0.0 pycparser-2.22 pyyaml-6.0.2 regex-2024.7.24 safetensors-0.4.4 sentencepiece-0.2.0 soundfile-0.12.1 spandrel-0.3.4 tokenizers-0.19.1 torchaudio-2.0.2 torchsde-0.2.6 tqdm-4.66.5 trampoline-0.1.2 transformers-4.44.0 yarl-1.9.4
# /kaggle/working/ui/custom_nodes
# Cloning into 'ComfyUI-Manager'...
# remote: Enumerating objects: 12478, done.
# remote: Counting objects: 100% (3322/3322), done.
# remote: Compressing objects: 100% (269/269), done.
# remote: Total 12478 (delta 3098), reused 3165 (delta 3053), pack-reused 9156 (from 1)
# Receiving objects: 100% (12478/12478), 10.88 MiB | 31.03 MiB/s, done.
# Resolving deltas: 100% (9211/9211), done.
# Cloning into 'comfyui_controlnet_aux'...
# remote: Enumerating objects: 4568, done.
# remote: Counting objects: 100% (1131/1131), done.
# remote: Compressing objects: 100% (307/307), done.
# remote: Total 4568 (delta 874), reused 955 (delta 818), pack-reused 3437 (from 1)
# Receiving objects: 100% (4568/4568), 29.89 MiB | 36.01 MiB/s, done.
# Resolving deltas: 100% (2461/2461), done.
# Cloning into 'ComfyUI_essentials'...
# remote: Enumerating objects: 374, done.
# remote: Counting objects: 100% (159/159), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 374 (delta 114), reused 119 (delta 86), pack-reused 215 (from 1)
# Receiving objects: 100% (374/374), 138.94 KiB | 5.79 MiB/s, done.
# Resolving deltas: 100% (220/220), done.
# Cloning into 'rgthree-comfy'...
# remote: Enumerating objects: 3226, done.
# remote: Counting objects: 100% (865/865), done.
# remote: Compressing objects: 100% (344/344), done.
# remote: Total 3226 (delta 609), reused 644 (delta 519), pack-reused 2361 (from 1)
# Receiving objects: 100% (3226/3226), 4.28 MiB | 31.10 MiB/s, done.
# Resolving deltas: 100% (2294/2294), done.
# Cloning into 'was-node-suite-comfyui'...
# remote: Enumerating objects: 2274, done.
# remote: Counting objects: 100% (862/862), done.
# remote: Compressing objects: 100% (344/344), done.
# remote: Total 2274 (delta 623), reused 683 (delta 510), pack-reused 1412 (from 1)
# Receiving objects: 100% (2274/2274), 39.55 MiB | 39.59 MiB/s, done.
# Resolving deltas: 100% (1387/1387), done.
# /kaggle/working/ui
# Cloning into 'ComfyUI-AnimateDiff-Evolved'...
# remote: Enumerating objects: 2478, done.
# remote: Counting objects: 100% (1131/1131), done.
# remote: Compressing objects: 100% (228/228), done.
# remote: Total 2478 (delta 976), reused 958 (delta 900), pack-reused 1347 (from 1)
# Receiving objects: 100% (2478/2478), 903.58 KiB | 14.57 MiB/s, done.
# Resolving deltas: 100% (1760/1760), done.
# Cloning into 'ComfyUI-Advanced-ControlNet'...
# remote: Enumerating objects: 1007, done.
# remote: Counting objects: 100% (407/407), done.
# remote: Compressing objects: 100% (184/184), done.
# remote: Total 1007 (delta 292), reused 309 (delta 220), pack-reused 600 (from 1)
# Receiving objects: 100% (1007/1007), 405.93 KiB | 5.27 MiB/s, done.
# Resolving deltas: 100% (688/688), done.
# Cloning into 'ComfyUI-VideoHelperSuite'...
# remote: Enumerating objects: 1941, done.
# remote: Counting objects: 100% (790/790), done.
# remote: Compressing objects: 100% (203/203), done.
# remote: Total 1941 (delta 696), reused 609 (delta 579), pack-reused 1151 (from 1)
# Receiving objects: 100% (1941/1941), 468.95 KiB | 13.40 MiB/s, done.
# Resolving deltas: 100% (1108/1108), done.
# [#ac2efe 1.6GiB/1.6GiB(98%) CN:16 DL:451MiB]0m]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# ac2efe|OK  |   448MiB/s|./ComfyUI-AnimateDiff-Evolved/models//mm_sd_v15_v2.ckpt
#
# Status Legend:
# (OK):download completed.
# [#3702b4 1.1GiB/1.5GiB(76%) CN:16 DL:435MiB]0m]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 3702b4|OK  |   439MiB/s|./ComfyUI-AnimateDiff-Evolved/models//mm_sd_v15.ckpt
#
# Status Legend:
# (OK):download completed.
# [#a19b07 1.3GiB/1.5GiB(89%) CN:16 DL:376MiB]0m]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# a19b07|OK  |   371MiB/s|./ComfyUI-AnimateDiff-Evolved/models//mm_sd_v14.ckpt
#
# Status Legend:
# (OK):download completed.
# [#309dc5 1.4GiB/1.5GiB(94%) CN:16 DL:411MiB]0m]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 309dc5|OK  |   411MiB/s|./ComfyUI-AnimateDiff-Evolved/models//temporaldiff-v1-animatediff.ckpt
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# e9fa15|OK  |   196MiB/s|./ComfyUI-AnimateDiff-Evolved/motion_lora//v2_lora_PanLeft.ckpt
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# a3f347|OK  |   202MiB/s|./ComfyUI-AnimateDiff-Evolved/motion_lora//v2_lora_PanRight.ckpt
#
# Status Legend:
# (OK):download completed.
# [#b228f5 72MiB/73MiB(98%) CN:1 DL:84MiB]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# b228f5|OK  |    69MiB/s|./ComfyUI-AnimateDiff-Evolved/motion_lora//v2_lora_ZoomOut.ckpt
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# c3f84c|OK  |   189MiB/s|./ComfyUI-AnimateDiff-Evolved/motion_lora//v2_lora_ZoomIn.ckpt
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 03a969|OK  |   215MiB/s|./ComfyUI-AnimateDiff-Evolved/motion_lora//v2_lora_TiltUp.ckpt
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# e6bc60|OK  |   210MiB/s|./ComfyUI-AnimateDiff-Evolved/motion_lora//v2_lora_TiltDown.ckpt
#
# Status Legend:
# (OK):download completed.
# Cloning into 'ComfyUI_IPAdapter_plus'...
# remote: Enumerating objects: 786, done.
# remote: Counting objects: 100% (429/429), done.
# remote: Compressing objects: 100% (126/126), done.
# remote: Total 786 (delta 397), reused 315 (delta 303), pack-reused 357 (from 1)
# Receiving objects: 100% (786/786), 4.72 MiB | 35.82 MiB/s, done.
# Resolving deltas: 100% (534/534), done.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 13b2d4|OK  |   111MiB/s|./ComfyUI_IPAdapter_plus/models//ip-adapter_sd15.bin
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 8dfae1|OK  |   315MiB/s|./ComfyUI_IPAdapter_plus/models//ip-adapter-plus_sd15.bin
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# d7c5e1|OK  |   230MiB/s|./ComfyUI_IPAdapter_plus/models//ip-adapter-plus-face_sd15.bin
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# aed440|OK  |   131MiB/s|./ComfyUI_IPAdapter_plus/models//ip-adapter_sd15_light.bin
#
# Status Legend:
# (OK):download completed.
# [#45b11f 2.0GiB/2.3GiB(86%) CN:16 DL:434MiB]0m]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 45b11f|OK  |   433MiB/s|../models/clip_vision//model.safetensors
#
# Status Legend:
# (OK):download completed.
# Cloning into 'ComfyUI-Impact-Pack'...
# remote: Enumerating objects: 4617, done.
# remote: Counting objects: 100% (1645/1645), done.
# remote: Compressing objects: 100% (284/284), done.
# remote: Total 4617 (delta 1474), reused 1501 (delta 1361), pack-reused 2972 (from 1)
# Receiving objects: 100% (4617/4617), 31.71 MiB | 47.89 MiB/s, done.
# Resolving deltas: 100% (3112/3112), done.
# /kaggle/working/ui
# [#657e68 2.0GiB/2.2GiB(90%) CN:16 DL:385MiB]0m]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 657e68|OK  |   377MiB/s|./models/checkpoints/dark_sushi_25d_25d.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 92e277|OK  |   166MiB/s|./models/upscale_models/RealESRGAN_x4.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 68bc24|OK  |   185MiB/s|./models/upscale_models/4x-UltraSharp.pth
#
# Status Legend:
# (OK):download completed.
# [#202a8f 291MiB/319MiB(91%) CN:16 DL:344MiB]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 202a8f|OK  |   345MiB/s|./models/vae/vae-ft-mse-840000-ema-pruned.vae.pt
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# ac1b2c|OK  |    64MiB/s|./models/loras/more_details.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# b8e3d8|OK  |   3.0MiB/s|./models/embeddings/EasyNegative.pt
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# a6472a|OK  |   2.3MiB/s|./models/embeddings/badhandv4.pt
#
# Status Legend:
# (OK):download completed.
# ln: failed to create symbolic link './models/loras/input': File exists
# m##############⠂⠂⠂⠂) ⠸ reify:localtunnel: timing reifyNode:node_modules/localtu[K[K
# added 22 packages in 939ms
#
# 3 packages are looking for funding
#   run `npm fund` for details
# npm notice
# npm notice New major version of npm available! 9.5.0 -> 10.8.2
# npm notice Changelog: https://github.com/npm/cli/releases/tag/v10.8.2
# npm notice Run npm install -g npm@10.8.2 to update!
# npm notice
# There are no unused tarball(s) to remove.
# Will remove 1 index cache(s).
# Will remove 23 (276.8 MB) package(s).
# There are no tempfile(s) to remove.
# There are no logfile(s) to remove.
# 설치 완료! 시작을 실행해주세요

# %%
# Ngrok 터널링을 이용하려면 키를 입력후 실행해주세요
# !pip install pyngrok
from pyngrok import conf, ngrok
conf.get_default().auth_token = "Your Ngrok key here"
conf.get_default().monitor_thread = False
ssh_tunnels = ngrok.get_tunnels(conf.get_default())
if len(ssh_tunnels) == 0:
  ssh_tunnel = ngrok.connect(8188)
  print('address：'+ssh_tunnel.public_url)
else:
  print('address：'+ssh_tunnels[0].public_url)

def iframe_thread(port):
  return
# Out:
# Collecting pyngrok
#   Downloading pyngrok-7.2.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: PyYAML>=5.1 in /opt/conda/lib/python3.10/site-packages (from pyngrok) (6.0)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.2.0
# address：https://c870-34-168-237-59.ngrok-free.app

# %%
# 시작 (localtunnel 터널링)

threading.Thread(target=iframe_thread, daemon=True, args=(8188,)).start()
# %cd {HomePath}/{Workspace}
# !/opt/conda/envs/colabui/bin/python3 main.py --dont-print-server
# Out:
# /kaggle/working/ui
# [START] Security scan
# [DONE] Security scan
# ## ComfyUI-Manager: installing dependencies. (GitPython)
# ## ComfyUI-Manager: installing dependencies done.
# ** ComfyUI startup time: 2024-08-15 06:22:07.000149
# ** Platform: Linux
# ** Python version: 3.10.5 | packaged by conda-forge | (main, Jun 14 2022, 07:04:59) [GCC 10.3.0]
# ** Python executable: /opt/conda/envs/colabui/bin/python3
# ** ComfyUI Path: /kaggle/working/ui
# ** Log path: /kaggle/working/ui/comfyui.log
#
# Prestartup times for custom nodes:
#    0.0 seconds: /kaggle/working/ui/custom_nodes/rgthree-comfy
#    8.2 seconds: /kaggle/working/ui/custom_nodes/ComfyUI-Manager
#
# ****** User settings have been changed to be stored on the server instead of browser storage. ******
# ****** For multi-user setups add the --multi-user CLI argument to enable multiple user profiles. ******
# WAS Node Suite: Created default conf file at `/kaggle/working/ui/custom_nodes/was-node-suite-comfyui/was_suite_config.json`.
# WAS Node Suite: OpenCV Python FFMPEG support is enabled
# WAS Node Suite Warning: `ffmpeg_bin_path` is not set in `/kaggle/working/ui/custom_nodes/was-node-suite-comfyui/was_suite_config.json` config file. Will attempt to use system ffmpeg binaries if available.
# WAS Node Suite: Finished. Loaded 218 nodes successfully.
#
# 	"Art is the lie that enables us to recognize the truth." - Friedrich Nietzsche
#
# [comfyui_controlnet_aux] | INFO -> Using ckpts path: /kaggle/working/ui/custom_nodes/comfyui_controlnet_aux/ckpts
# [comfyui_controlnet_aux] | INFO -> Using symlinks: False
# [comfyui_controlnet_aux] | INFO -> Using ort providers: ['CUDAExecutionProvider', 'DirectMLExecutionProvider', 'OpenVINOExecutionProvider', 'ROCMExecutionProvider', 'CPUExecutionProvider', 'CoreMLExecutionProvider']
# /kaggle/working/ui/custom_nodes/comfyui_controlnet_aux/node_wrappers/dwpose.py:26: UserWarning: DWPose: Onnxruntime not found or doesn't come with acceleration providers, switch to OpenCV with CPU device. DWPose might run very slowly
#   warnings.warn("DWPose: Onnxruntime not found or doesn't come with acceleration providers, switch to OpenCV with CPU device. DWPose might run very slowly")
# ### Loading: ComfyUI-Manager (V2.48.8)
# ### ComfyUI Revision: 2542 [0f9c2a78] | Released on '2024-08-14'
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/model-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/alter-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/github-stats.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/extension-node-map.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/custom-node-list.json
#
# [rgthree] Loaded 42 fantastic nodes.
# [rgthree] Will use rgthree's optimized recursive execution.
#
# FETCH DATA from: /kaggle/working/ui/custom_nodes/ComfyUI-Manager/extension-node-map.json [DONE]
# FETCH DATA from: /kaggle/working/ui/custom_nodes/ComfyUI-Manager/.cache/1742899825_extension-node-map.json [DONE]
# FETCH DATA from: /kaggle/working/ui/custom_nodes/ComfyUI-Manager/.cache/1514988643_custom-node-list.json [DONE]
# FETCH DATA from: /kaggle/working/ui/custom_nodes/ComfyUI-Manager/.cache/746607195_github-stats.json [DONE]
# FETCH DATA from: /kaggle/working/ui/custom_nodes/ComfyUI-Manager/.cache/1742899825_extension-node-map.json [DONE]
# FETCH DATA from: /kaggle/working/ui/custom_nodes/ComfyUI-Manager/.cache/1514988643_custom-node-list.json [DONE]
# FETCH DATA from: /kaggle/working/ui/custom_nodes/ComfyUI-Manager/.cache/746607195_github-stats.json [DONE]
# FETCH DATA from: /kaggle/working/ui/custom_nodes/ComfyUI-Manager/.cache/1742899825_extension-node-map.json [DONE]

# %%
# output download

# !zip -q -r output.zip {HomePath}/{Workspace}/output
# !mv {HomePath}/{Workspace}/output.zip {HomePath}/output.zip

# %cd {HomePath}
from IPython.display import FileLink
FileLink('output.zip')

# %%
# output delete

# !rm {HomePath}/output.zip
# !rm -r {HomePath}/{Workspace}/output/
